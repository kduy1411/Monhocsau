# %% [markdown]
# <a href="https://colab.research.google.com/github/kduy1411/Monhocsau/blob/main/lab05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.graphics.gofplots import qqplot

# %%
data = pd.read_csv("/content/data/babies.txt",sep="\s+")
print(data)
# Out:
#       bwt  smoke
# 0     120      0
# 1     113      0
# 2     128      1
# 3     123      0
# 4     108      1
# ...   ...    ...
# 1231  113      0
# 1232  128      0
# 1233  130      1
# 1234  125      0
# 1235  117      0
#
# [1236 rows x 2 columns]

# %%
df_cohutthuoc=data[data['smoke']==1]

# %%
df_khonghutthuoc=data[data['smoke']==0]

# %%
data.boxplot(by='smoke',column=['bwt'])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
df_cohutthuoc.describe()
# Out:
#               bwt  smoke
# count  484.000000  484.0
# mean   114.109504    1.0
# std     18.098946    0.0
# min     58.000000    1.0
# 25%    102.000000    1.0
# 50%    115.000000    1.0
# 75%    126.000000    1.0
# max    163.000000    1.0

# %%
print('Kurtosis la: ',df_cohutthuoc['bwt'].kurtosis()+3)
print('Skew la:',df_cohutthuoc['bwt'].skew())
print('Min la:',df_cohutthuoc['bwt'].min())
print('Max la:',df_cohutthuoc['bwt'].max())
print('Mean la:',df_cohutthuoc['bwt'].mean())
print('std la:',df_cohutthuoc['bwt'].std())
print('var la:',df_cohutthuoc['bwt'].var())
print('Q0%',df_cohutthuoc['bwt'].quantile(.0))
print('Q25%',df_cohutthuoc['bwt'].quantile(.25))
print('Q50%',df_cohutthuoc['bwt'].quantile(.50))
print('Q75%',df_cohutthuoc['bwt'].quantile(.75))
# Out:
# Kurtosis la:  3.0004078135961083
# Skew la: -0.033699506713282625
# Min la: 58
# Max la: 163
# Mean la: 114.10950413223141
# std la: 18.098945686152376
# var la: 327.5718349502937
# Q0% 58.0
# Q25% 102.0
# Q50% 115.0
# Q75% 126.0

# %%
#IQR=Q3=Q1(Q75%-Q25%)
df_cohutthuoc.hist(column='bwt',bins=12)

df_khonghutthuoc.hist(column='bwt',bins=6)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7c40422bd0>]],
#       dtype=object)

# %%
#cách dùng thư viện matplotlib
plt.hist(df_cohutthuoc['bwt'],bins=12)
plt.show()

qqplot(df_cohutthuoc['bwt'],line='s')

qqplot(df_khonghutthuoc['bwt'],line='s')
